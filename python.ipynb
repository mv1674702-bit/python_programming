# %%
num=int(input("enter the number:"))
if num%2==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
def list_count(num):
    count=0
    for i in num:
        if i == 4:
             count+=1
    return count
    
print(list_count([3,4,6,4,2,7,5,4]))
# Out:
# 3
